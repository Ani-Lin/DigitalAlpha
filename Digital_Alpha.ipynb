# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
home_values_df = pd.read_csv('Digital_Alpha\\ZHV1_bedroom.csv')

# %%
home_values_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2000-01-31  \
# 0    102001         0    United States    country       NaN     85447.0
# 1    394913         1     New York, NY        msa        NY    160418.0
# 2    753899         2  Los Angeles, CA        msa        CA    133286.0
# 3    394463         3      Chicago, IL        msa        IL    110847.0
# 4    394514         4       Dallas, TX        msa        TX     78764.0
#
#    2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2021-12-31  \
# 0     85730.0     86041.0     86674.0     87299.0  ...    228646.0
# 1    161442.0    162282.0    163990.0    165624.0  ...    429991.0
# 2    133848.0    134689.0    136255.0    137942.0  ...    507026.0
# 3    111115.0    111639.0    112639.0    113778.0  ...    182456.0
# 4     78959.0     78527.0     78103.0     77974.0  ...    172115.0
#
#    2022-01-31  2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  \
# ...

# %%
home_values_df.isnull().sum()
# Out:
# RegionID       0
# SizeRank       0
# RegionName     0
# RegionType     0
# StateName      1
#               ..
# 2022-05-31    11
# 2022-06-30    10
# 2022-07-31     8
# 2022-08-31     4
# 2022-09-30     0
# Length: 278, dtype: int64

# %%
home_values_df['2022-05-31'].fillna(value=home_values_df['2022-05-31'].mean(), inplace=True)
home_values_df['2022-06-30'].fillna(value=home_values_df['2022-06-30'].mean(), inplace=True)
home_values_df['2022-07-31'].fillna(value=home_values_df['2022-07-31'].mean(), inplace=True)
home_values_df['2022-08-31'].fillna(value=home_values_df['2022-08-31'].mean(), inplace=True)
home_values_df['2022-09-30'].fillna(value=home_values_df['2022-09-30'].mean(), inplace=True)

# %%
home_values_df.isnull().sum()
# Out:
# RegionID      0
# SizeRank      0
# RegionName    0
# RegionType    0
# StateName     1
#              ..
# 2022-05-31    0
# 2022-06-30    0
# 2022-07-31    0
# 2022-08-31    0
# 2022-09-30    0
# Length: 278, dtype: int64

# %%
import matplotlib.pyplot as plt

test_df=home_values_df.groupby(['RegionName'])['2022-05-31'].max()
test_df
# Out:
# RegionName
# Aberdeen, SD      108965.0
# Aberdeen, WA      240984.0
# Abilene, TX       118346.0
# Ada, OK            56750.0
# Adrian, MI        182937.0
#                     ...
# York, PA          150712.0
# Youngstown, OH     70790.0
# Yuba City, CA     287424.0
# Yuma, AZ          176915.0
# Zanesville, OH     87602.0
# Name: 2022-05-31, Length: 777, dtype: float64

# %%
#fig = plt.figure(figsize = (20, 20))
 
# creating the bar plot]

test_df.plot(kind='line', title='Region wise max price', ylabel='Price',xlabel='Region', figsize=(20, 10))
plt.show()
